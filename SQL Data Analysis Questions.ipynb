# %% [markdown]
# # Objective
#
# The objective of this notebook is to demonstrate SQL queries using MySql workbench. The questions for review represent inqueries from the Sales Director regarding customer data from 2017 to 2020.

# %% [markdown]
# ## Data Analysis Questions
# 1. For what years do we have customer data?
# 2. What is the total revenue for 2020?
# 3. What are the top five selling products by percentage of revenue from Miami market?
# 4. What are the sales ranking by Zone?
# 5. Which customers order the most?
# 6. Which month had highest volume of sales in 2019?

# %% [markdown]
# ### 1. For what years do we have customer data?

# %% [markdown]
# ![pic1.png](attachment:pic1.png)

# %% [markdown]
# ### 2. What is the total revenue for 2020?

# %% [markdown]
# ![pic2.png](attachment:pic2.png)

# %% [markdown]
# ### 3. What are the top five selling products by percentage of revenue from Miami market?

# %% [markdown]
# ![pic3.png](attachment:pic3.png)

# %% [markdown]
# ### 4. What are the sales ranking by Zone?

# %% [markdown]
# ![pic4.png](attachment:pic4.png)

# %% [markdown]
# ### 5. Which customers order the most?

# %% [markdown]
# ![pic5.png](attachment:pic5.png)

# %% [markdown]
# ### 6. Which month had highest volume of sales in 2019?

# %% [markdown]
# ![pic6.png](attachment:pic6.png)
